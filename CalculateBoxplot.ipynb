# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF

from pandas import Series, DataFrame
import numpy as np
import pandas as pd

# %%
plotly.tools.set_credentials_file(username='ally53628', api_key='5reOBCbokSUCRKbPmcH3')

# %%
TacticName = 'Pronged'

spaceID0 = 'Pronged_8x8_0425035002'
gameObjectID0 = '0425035005'

spaceID1 = 'Pronged_8x8_0425035009'
gameObjectID1 = '0425035012'

spaceID2 = 'Pronged_8x8_0425035015'
gameObjectID2 = '0425035018'

spaceID3 = 'Pronged_8x8_0425035022'
gameObjectID3 = '0425035025'

spaceID4 = 'Pronged_8x8_0425035028'
gameObjectID4 = '0425035031'

spaceID5 = 'Pronged_8x8_0425035034'
gameObjectID5 = '0425035037'

spaceID6 = 'Pronged_8x8_0425035039'
gameObjectID6 = '0425035042'

spaceID7 = 'Pronged_8x8_0425035045'
gameObjectID7 = '0425035048'

spaceID8 = 'Pronged_8x8_0425035051'
gameObjectID8 = '0425035054'

spaceID9 = 'Pronged_8x8_0425035057'
gameObjectID9 = '0425035100'

spaceIDList = [spaceID0, spaceID1, spaceID2, spaceID3, spaceID4, spaceID5, spaceID6, spaceID7, spaceID8, spaceID9]
gameObjectIDList = [gameObjectID0, gameObjectID1, gameObjectID2, gameObjectID3, gameObjectID4, 
                    gameObjectID5, gameObjectID6, gameObjectID7, gameObjectID8, gameObjectID9]

# %%
def getData(spaceIDList, Generation, Fitness_RectangleQuality=False, Fitness_CorridorQuality=False, 
            Fitness_ConnectedQuality=False, SumOfSpaceFitnessScore=False, 
            Fitness_MainPathQuality=False, Fitness_Defense=False, 
            Fitness_OnMainPath_EnemyTrap=False, Fitness_OnMainPath_Treasure=False, 
            Fitness_BesideMainPath_EnemyTrap=False, Fitness_BesideMainPath_Treasure=False, 
            Fitness_TwoPronged=False, SumOfGameObjectFitnessScore=False):
    # Create the new list
    List = []
   
    # Get the value from data
    if Fitness_RectangleQuality is True:
        needCalculate=True
        Fitness='Fitness_RectangleQuality'
    elif Fitness_CorridorQuality is True:
        needCalculate=True
        Fitness='Fitness_CorridorQuality'
    elif Fitness_ConnectedQuality is True:
        needCalculate=True
        Fitness='Fitness_ConnectedQuality'
    elif SumOfSpaceFitnessScore is True:
        needCalculate=True
        Fitness='SumOfSpaceFitnessScore'
    elif Fitness_MainPathQuality is True:
        needCalculate=True
        Fitness='Fitness_MainPathQuality'
    elif Fitness_Defense is True:
        needCalculate=True
        Fitness='Fitness_Defense'
    elif Fitness_OnMainPath_EnemyTrap is True:
        needCalculate=True
        Fitness='Fitness_OnMainPath_EnemyTrap'
    elif Fitness_OnMainPath_Treasure is True:
        needCalculate=True
        Fitness='Fitness_OnMainPath_Treasure'
    elif Fitness_BesideMainPath_EnemyTrap is True:
        needCalculate=True
        Fitness='Fitness_BesideMainPath_EnemyTrap'
    elif Fitness_BesideMainPath_Treasure is True:
        needCalculate=True
        Fitness='Fitness_BesideMainPath_Treasure'
    elif Fitness_TwoPronged is True:
        needCalculate=True
        Fitness='Fitness_TwoPronged'
    elif SumOfGameObjectFitnessScore is True:
        needCalculate=True
        Fitness='SumOfGameObjectFitnessScore'
    else:
        needCalculate=False
    
    if needCalculate is True:
        for i in range(0, 10, 1):
            #input table
            spaceID = spaceIDList[i]
            orlData = pd.read_csv("./Experiment_01_output/output_"+ spaceID +".csv")
            List.append(orlData[Fitness][Generation])
        
    return List

# %%
# Create a new table for all generation in different Run
# Create new table
Table = DataFrame()

for i in range(0, 51, 1):
    runList = getData(spaceIDList, i, Fitness_BesideMainPath_EnemyTrap=True)
    Table[i] = Series(runList)

Table
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.050866  0.047274  0.059750  0.093107  0.082500  0.075833  0.065833
# 1  0.046156  0.045329  0.039426  0.031952  0.034548  0.037708  0.025000
# 2  0.046890  0.042440  0.065869  0.048125  0.044750  0.040667  0.027024
# 3  0.062272  0.041301  0.045229  0.036473  0.035905  0.032086  0.028238
# 4  0.052568  0.024077  0.011542  0.019583  0.037875  0.083196  0.067292
# 5  0.035281  0.033979  0.060542  0.099500  0.084333  0.085833  0.088583
# 6  0.063890  0.052631  0.055435  0.080399  0.090518  0.084696  0.089750
# 7  0.044890  0.055667  0.068844  0.076217  0.055688  0.066917  0.059113
# 8  0.056249  0.046994  0.034103  0.039326  0.043268  0.029336  0.031801
# 9  0.049437  0.057937  0.053750  0.061083  0.047250  0.070792  0.057250
#
#          7         8         9     ...           41        42        43  \
# 0  0.049167  0.027167  0.036000    ...     0.000000  0.000000  0.000000
# 1  0.012077  0.018161  0.041833    ...     0.083333  0.083333  0.083333
# 2  0.012086  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 3  0.066452  0.062128  0.060625    ...     0.062500  0.062500  0.062500
# 4  0.079375  0.095625  0.095833    ...     0.000000  0.000000  0.000000
# 5  0.095083  0.105583  0.105083    ...     0.083333  0.083333  0.083333
# 6  0.084000  0.056000  0.064167    ...     0.075000  0.075000  0.075000
# 7  0.039092  0.029062  0.025792    ...     0.020833  0.020833  0.020833
# 8  0.032948  0.071542  0.099646    ...     0.166667  0.166667  0.166667
# 9  0.038958  0.017917  0.025833    ...     0.083333  0.083333  0.083333
#
#          44        45        46        47        48        49        50
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.062500  0.062500  0.062500  0.062500  0.062500  0.062500  0.062500
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333
# 6  0.075000  0.075000  0.075000  0.075000  0.075000  0.075000  0.075000
# 7  0.020833  0.020833  0.020833  0.020833  0.020833  0.020833  0.020833
# 8  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 9  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333  0.083333
#
# [10 rows x 51 columns]

# %%
Table_Mean = DataFrame()

for i in range(0, 51, 1):
    valueList = []
    valueList.append(Table[i].mean())  
    Table_Mean[i] = Series(valueList)

Table_Mean
# Out:
#         0         1         2         3         4         5         6   \
# 0  0.05085  0.044763  0.049449  0.058577  0.055663  0.060707  0.053988
#
#          7         8         9    ...        41      42      43      44  \
# 0  0.050924  0.048318  0.055481   ...    0.0575  0.0575  0.0575  0.0575
#
#        45      46      47      48      49      50
# 0  0.0575  0.0575  0.0575  0.0575  0.0575  0.0575
#
# [1 rows x 51 columns]

# %%
data = []

trace0 = go.Scatter(
    x=list(Table),
    y=Table_Mean.iloc[0],
    marker=dict(
        color='rgb(142, 53, 74)',
    ),
    mode = 'lines+markers',
    name = 'Fitness'
)
data.append(trace0)

for i in range(0, 51, 1):
    trace = go.Box(
    y=Table[i],
    name = str(i),
    marker=dict(
        color='rgb(28, 28, 28)',
    ),
    boxmean=True)
    data.append(trace)

layout = go.Layout(title='Tactic：'+TacticName+'／Fitness Function：BesideMainPath_EnemyTrap', titlefont=dict(size=30, color='#000000'),
                   xaxis=dict(title='Generation', titlefont=dict(size=18, color='#000000')),
                   yaxis=dict(title='Fitness Score', titlefont=dict(size=18, color='#000000')))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ally53628/72.embed" height="525px" width="100%"></iframe>
